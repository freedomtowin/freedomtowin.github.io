# %%
html = """
<section class="u-marginTop30 u-xs-margin0 u-marginBottom15 u-maxWidth1032 u-sm-paddingLeft20 u-sm-paddingRight20 u-borderBox u-marginAuto"><div class="row u-marginTop30 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight15 u-size8of12" data-source="collection_home---4------0-----------------------" data-post-id="b8fea36f71c2" data-index="0" data-scroll="native"><div class="u-lineHeightBase postItem u-marginRight3"><a href="https://medium.com/init-deep-dive/should-rust-get-gud-or-should-you-b8fea36f71c2?source=collection_home---4------0-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/should-rust-get-gud-or-should-you-b8fea36f71c2?source=collection_home---4------0-----------------------" class="u-block u-xs-height170 u-height350 u-width100pct u-floatLeft  u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/900/1*c0WuZ4XiDfw5-aJ4bMMaIQ.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Should Rust “get gud” or Should You?  🦀</span></a></div></div><div class="col u-xs-marginBottom10 u-paddingLeft9 u-paddingRight12 u-paddingTop0 u-sm-paddingTop20 u-paddingBottom25 u-size4of12 u-xs-size12of12 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/should-rust-get-gud-or-should-you-b8fea36f71c2?source=collection_home---4------0-----------------------" data-action-source="collection_home---4------0-----------------------" data-post-id="b8fea36f71c2"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp4 u-fontSize30 u-size12of12 u-xs-size12of12 u-xs-fontSize24">Should Rust “get gud” or Should You?  🦀</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">A Brief Analysis Rust’s Pain&nbsp;Points</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2025-02-25T22:45:43.649Z">Feb 25</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="5 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="row u-marginTop15 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------1-----------------------" data-post-id="f7a6fcf7b814" data-index="1" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/my-reflections-on-tech-ai-in-2024-f7a6fcf7b814?source=collection_home---4------1-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/my-reflections-on-tech-ai-in-2024-f7a6fcf7b814?source=collection_home---4------1-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*j1tl5MvKm-Loyz8Nd6Zjsw.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">My Reflections on Tech &amp; AI in 2024</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/my-reflections-on-tech-ai-in-2024-f7a6fcf7b814?source=collection_home---4------1-----------------------" data-action-source="collection_home---4------1-----------------------" data-post-id="f7a6fcf7b814"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">My Reflections on Tech &amp; AI in&nbsp;2024</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Notes on My Personal Growth and Opinions on the Benefits of&nbsp;GenAI</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2025-01-03T23:59:09.178Z">Jan 3</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="4 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------2-----------------------" data-post-id="74b575d02505" data-index="2" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/langgraph-self-correcting-code-assistant-rag-search-74b575d02505?source=collection_home---4------2-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/langgraph-self-correcting-code-assistant-rag-search-74b575d02505?source=collection_home---4------2-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/0*fCPPvaoVMpArbASS.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">[LangGraph] Self-Correcting Code Assistant + Rag Search</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/langgraph-self-correcting-code-assistant-rag-search-74b575d02505?source=collection_home---4------2-----------------------" data-action-source="collection_home---4------2-----------------------" data-post-id="74b575d02505"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">[LangGraph] Self-Correcting Code Assistant + Rag&nbsp;Search</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">AI Agent for Code Generation with RAG + Self-Reflection</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-10-23T02:24:01.113Z">Oct 22, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="6 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------3-----------------------" data-post-id="4ab9f50e017c" data-index="3" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/linkedin-easy-apply-bot-with-chatgpt-4o-and-langgraph-agent-4ab9f50e017c?source=collection_home---4------3-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/linkedin-easy-apply-bot-with-chatgpt-4o-and-langgraph-agent-4ab9f50e017c?source=collection_home---4------3-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/0*4L8eMzAqeshGSSM2.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">LinkedIn Easy-Apply Bot with ChatGPT 4o and LangGraph Agent</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/linkedin-easy-apply-bot-with-chatgpt-4o-and-langgraph-agent-4ab9f50e017c?source=collection_home---4------3-----------------------" data-action-source="collection_home---4------3-----------------------" data-post-id="4ab9f50e017c"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">LinkedIn Easy-Apply Bot with ChatGPT 4o and LangGraph Agent</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Web Automation and Data Collection</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-09-23T23:44:31.341Z">Sep 23, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="4 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div></div><div class="row u-marginTop15 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------4-----------------------" data-post-id="d23731e5385b" data-index="4" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/python-finetune-any-open-source-llm-as-a-re-ranker-d23731e5385b?source=collection_home---4------4-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/python-finetune-any-open-source-llm-as-a-re-ranker-d23731e5385b?source=collection_home---4------4-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/0*u5uM8SA_R9lbBQEZ.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">[Python] Finetune any Open-Source LLM as a Re-Ranker</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/python-finetune-any-open-source-llm-as-a-re-ranker-d23731e5385b?source=collection_home---4------4-----------------------" data-action-source="collection_home---4------4-----------------------" data-post-id="d23731e5385b"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">[Python] Finetune any Open-Source LLM as a Re-Ranker</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Pairwise Ranking Prompting Strategy for Open-Source and API-Based LLMs</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-08-28T18:18:19.870Z">Aug 28, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="5 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------5-----------------------" data-post-id="30193180be32" data-index="5" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/voice-cloning-with-tacotron2-and-hifi-gan-30193180be32?source=collection_home---4------5-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/voice-cloning-with-tacotron2-and-hifi-gan-30193180be32?source=collection_home---4------5-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*7T-xFreB7qs1-z3W3KSF_A.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Voice Cloning with Tacotron2 and HiFi-GAN</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/voice-cloning-with-tacotron2-and-hifi-gan-30193180be32?source=collection_home---4------5-----------------------" data-action-source="collection_home---4------5-----------------------" data-post-id="30193180be32"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Voice Cloning with Tacotron2 and&nbsp;HiFi-GAN</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Fine-tuning Text-Wav and Wav-Speech models</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-08-09T18:14:01.694Z">Aug 9, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="5 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------6-----------------------" data-post-id="6848421404dc" data-index="6" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/full-stack-creating-a-transactions-database-with-bare-bones-aws-services-for-a-hypothetical-web-6848421404dc?source=collection_home---4------6-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/full-stack-creating-a-transactions-database-with-bare-bones-aws-services-for-a-hypothetical-web-6848421404dc?source=collection_home---4------6-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/0*HnI_ciIj31NyLAlt.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">[AWS] Creating a Transactions Database with Bare Bones AWS Services for a Hypothetical Web App</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/full-stack-creating-a-transactions-database-with-bare-bones-aws-services-for-a-hypothetical-web-6848421404dc?source=collection_home---4------6-----------------------" data-action-source="collection_home---4------6-----------------------" data-post-id="6848421404dc"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">[AWS] Creating a Transactions Database with Bare Bones AWS Services for a Hypothetical Web&nbsp;App</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Integrating a Web App with DynamoDB, API Gateway, and&nbsp;Cognito</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-07-27T23:27:46.275Z">Jul 27, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="8 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div></div><div class="row u-marginTop15 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------7-----------------------" data-post-id="3fc937a1348d" data-index="7" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/image-hashing-networks-with-metric-learning-3fc937a1348d?source=collection_home---4------7-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/image-hashing-networks-with-metric-learning-3fc937a1348d?source=collection_home---4------7-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*KKgkfsH2T896HekUyXdEsw.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Image Hashing Networks with Metric Learning</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/image-hashing-networks-with-metric-learning-3fc937a1348d?source=collection_home---4------7-----------------------" data-action-source="collection_home---4------7-----------------------" data-post-id="3fc937a1348d"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Image Hashing Networks with Metric&nbsp;Learning</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Inspired by Apple’s CSAM Image Hashing Algorithm</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-07-22T22:52:30.422Z">Jul 22, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="5 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------8-----------------------" data-post-id="cecadd083aec" data-index="8" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/rust-quantized-llama-3-gguf-on-a-gpu-with-candle-rs-cecadd083aec?source=collection_home---4------8-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/rust-quantized-llama-3-gguf-on-a-gpu-with-candle-rs-cecadd083aec?source=collection_home---4------8-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*z7AHm7tw-unR475vyAlixA.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">[Rust] Serving Llama 3 Quantized (GGUF) on GPU with Candle-RS and Tide</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/rust-quantized-llama-3-gguf-on-a-gpu-with-candle-rs-cecadd083aec?source=collection_home---4------8-----------------------" data-action-source="collection_home---4------8-----------------------" data-post-id="cecadd083aec"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">[Rust] Serving Llama 3 Quantized (GGUF) on GPU with Candle-RS and&nbsp;Tide</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Serving Quantized Llama 3 Model on a GPU on Windows&nbsp;11</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-07-20T18:30:23.328Z">Jul 20, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="9 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------9-----------------------" data-post-id="1403d3d1067a" data-index="9" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/testing-aws-docker-golang-lambda-locally-on-windows-11-1403d3d1067a?source=collection_home---4------9-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/testing-aws-docker-golang-lambda-locally-on-windows-11-1403d3d1067a?source=collection_home---4------9-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*xyBAqdK5boGVq8UfMTGPTw.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Testing AWS Lambda with Docker Golang on Windows 11 Locally</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/testing-aws-docker-golang-lambda-locally-on-windows-11-1403d3d1067a?source=collection_home---4------9-----------------------" data-action-source="collection_home---4------9-----------------------" data-post-id="1403d3d1067a"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Testing AWS Lambda with Docker Golang on Windows 11&nbsp;Locally</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">The setup for testing AWS Golang Lambda locally on 7/17/2024</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-07-17T08:23:19.997Z">Jul 17, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="3 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div></div><div class="row u-marginTop15 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------10-----------------------" data-post-id="4d33fcc99405" data-index="10" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/rust-video-frame-extraction-speed-comparison-4d33fcc99405?source=collection_home---4------10-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/rust-video-frame-extraction-speed-comparison-4d33fcc99405?source=collection_home---4------10-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*lF3z42B7BnqQbZNOrLraig.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">[Rust] Video Frame Extraction Speed Comparison</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/rust-video-frame-extraction-speed-comparison-4d33fcc99405?source=collection_home---4------10-----------------------" data-action-source="collection_home---4------10-----------------------" data-post-id="4d33fcc99405"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">[Rust] Video Frame Extraction Speed Comparison</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">FFMPEG-Next vs OpenCV vs&nbsp;Video-RS</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-07-09T22:12:22.741Z">Jul 9, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="6 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------11-----------------------" data-post-id="83038cc11af3" data-index="11" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/setting-up-a-dev-container-on-windows-11-for-rust-development-83038cc11af3?source=collection_home---4------11-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/setting-up-a-dev-container-on-windows-11-for-rust-development-83038cc11af3?source=collection_home---4------11-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*Iz5Z8rzG7ka8N8gkEZqEFg.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Setting up a Dev Container on Windows 11 for Rust Development</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/setting-up-a-dev-container-on-windows-11-for-rust-development-83038cc11af3?source=collection_home---4------11-----------------------" data-action-source="collection_home---4------11-----------------------" data-post-id="83038cc11af3"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Setting up a Dev Container on Windows 11 for Rust Development</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">LLVM, FFMPEG, and OpenCV on Windows 11 in a Dev Container</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-07-09T03:49:51.636Z">Jul 8, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="2 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------12-----------------------" data-post-id="b0f8db0b3b59" data-index="12" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/advanced-rag-cookbook-b0f8db0b3b59?source=collection_home---4------12-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/advanced-rag-cookbook-b0f8db0b3b59?source=collection_home---4------12-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*4s4N9rpxEwDRfT8DZT28Mg.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Advanced RAG Cookbook</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/advanced-rag-cookbook-b0f8db0b3b59?source=collection_home---4------12-----------------------" data-action-source="collection_home---4------12-----------------------" data-post-id="b0f8db0b3b59"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Advanced RAG&nbsp;Cookbook</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Code Examples and Practical Use Cases for Advanced&nbsp;RAG</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-07-01T23:06:26.931Z">Jul 1, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="16 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div></div><div class="row u-marginTop15 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------13-----------------------" data-post-id="88e1bd4c49fe" data-index="13" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/rust-comparing-rustformers-and-candle-for-llm-inference-88e1bd4c49fe?source=collection_home---4------13-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/rust-comparing-rustformers-and-candle-for-llm-inference-88e1bd4c49fe?source=collection_home---4------13-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*wnT0sLFGd0FJPnhrHuV6rA.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">[Rust] Comparing Rustformers and Candle for LLM Inference</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/rust-comparing-rustformers-and-candle-for-llm-inference-88e1bd4c49fe?source=collection_home---4------13-----------------------" data-action-source="collection_home---4------13-----------------------" data-post-id="88e1bd4c49fe"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">[Rust] Comparing Rustformers and Candle for LLM Inference</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Running Meta/Llama Models&nbsp;Locally</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-05-30T20:03:48.922Z">May 30, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="8 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------14-----------------------" data-post-id="239bd8dd92a9" data-index="14" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/creating-an-llm-web-app-gpt-researcher-239bd8dd92a9?source=collection_home---4------14-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/creating-an-llm-web-app-gpt-researcher-239bd8dd92a9?source=collection_home---4------14-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*SQqD378Vi3Lt9bFd2UanRw.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Creating an LLM Web App — GPT Researcher</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/creating-an-llm-web-app-gpt-researcher-239bd8dd92a9?source=collection_home---4------14-----------------------" data-action-source="collection_home---4------14-----------------------" data-post-id="239bd8dd92a9"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Creating an LLM Web App — GPT Researcher</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">I hesitated a whole week to write this post because 50% of the tech stack in this post was learned, tested, and deployed in around a&nbsp;month…</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2024-02-24T03:56:09.896Z">Feb 23, 2024</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="3 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------15-----------------------" data-post-id="b69828eb4d36" data-index="15" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/building-a-ci-cd-pipeline-for-a-flask-react-openai-web-app-with-aws-golang-cdk-b69828eb4d36?source=collection_home---4------15-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/building-a-ci-cd-pipeline-for-a-flask-react-openai-web-app-with-aws-golang-cdk-b69828eb4d36?source=collection_home---4------15-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*f-9qpvYcbOL4E7aEDCrHUw.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Building a CI/CD Pipeline for a Flask-React OpenAI Web App with AWS Golang CDK</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/building-a-ci-cd-pipeline-for-a-flask-react-openai-web-app-with-aws-golang-cdk-b69828eb4d36?source=collection_home---4------15-----------------------" data-action-source="collection_home---4------15-----------------------" data-post-id="b69828eb4d36"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Building a CI/CD Pipeline for a Flask-React OpenAI Web App with AWS Golang&nbsp;CDK</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">This article combines and modifies the AWS Go CDK “codepipeline-build-deploy” example and a “react-flask-app” example to create a&nbsp;simple…</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2023-12-10T14:38:33.185Z">Dec 10, 2023</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="7 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div></div><div class="row u-marginTop15 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------16-----------------------" data-post-id="f5d48599385b" data-index="16" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/api-speed-tests-of-python-rust-extensions-in-aws-lambda-f5d48599385b?source=collection_home---4------16-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/api-speed-tests-of-python-rust-extensions-in-aws-lambda-f5d48599385b?source=collection_home---4------16-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*Q6Tpe0uQ7zYvQd6dzEWwPw.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">API Speed Tests of Python-Rust Extensions in AWS Lambda</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/api-speed-tests-of-python-rust-extensions-in-aws-lambda-f5d48599385b?source=collection_home---4------16-----------------------" data-action-source="collection_home---4------16-----------------------" data-post-id="f5d48599385b"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">API Speed Tests of Python-Rust Extensions in AWS&nbsp;Lambda</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Rust is a new-ish programming language that has the potential to displace other programming language in the data engineering space. This&nbsp;is…</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2023-11-25T06:14:10.324Z">Nov 25, 2023</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="9 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------17-----------------------" data-post-id="742298d26865" data-index="17" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/simple-huggingface-youtube-summarizer-pipeline-and-athena-db-huggingface-openai-742298d26865?source=collection_home---4------17-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/simple-huggingface-youtube-summarizer-pipeline-and-athena-db-huggingface-openai-742298d26865?source=collection_home---4------17-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*ICvDYXCR2B2uai1Y7UsRXA.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Simple HuggingFace YouTube Summarizer Pipeline and Athena DB (HuggingFace/OpenAI)</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/simple-huggingface-youtube-summarizer-pipeline-and-athena-db-huggingface-openai-742298d26865?source=collection_home---4------17-----------------------" data-action-source="collection_home---4------17-----------------------" data-post-id="742298d26865"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Simple HuggingFace YouTube Summarizer Pipeline and Athena DB (HuggingFace/OpenAI)</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Google Maps</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2023-11-19T23:18:32.413Z">Nov 19, 2023</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="8 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------18-----------------------" data-post-id="958609f60f3f" data-index="18" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/creating-a-real-time-gpt-2-chatbot-in-world-of-warcraft-958609f60f3f?source=collection_home---4------18-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/creating-a-real-time-gpt-2-chatbot-in-world-of-warcraft-958609f60f3f?source=collection_home---4------18-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*XIJ7kIAylcQ1MXk_QC-RRg.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Creating A Real-Time (Fine-Tuned) GPT-2 Chatbot in World of Warcraft</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/creating-a-real-time-gpt-2-chatbot-in-world-of-warcraft-958609f60f3f?source=collection_home---4------18-----------------------" data-action-source="collection_home---4------18-----------------------" data-post-id="958609f60f3f"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Creating A Real-Time (Fine-Tuned) GPT-2 Chatbot in World of&nbsp;Warcraft</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">I created a “fine-tuned” chat bot, with GPT-2, to responded to players in a video game called world of warcraft (WoW). Why am I doing&nbsp;this…</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2023-03-07T15:49:38.510Z">Mar 7, 2023</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="11 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div></div><div class="row u-marginTop15 u-marginLeftNegative12 u-marginRightNegative12"><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------19-----------------------" data-post-id="ce8f770fdb5b" data-index="19" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/reinforcement-learning-to-approximate-mixed-integer-allocation-solutions-on-simulated-data-ce8f770fdb5b?source=collection_home---4------19-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/reinforcement-learning-to-approximate-mixed-integer-allocation-solutions-on-simulated-data-ce8f770fdb5b?source=collection_home---4------19-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*AIYhDb_NxDre3Ezy5qNPBg@2x.jpeg&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Reinforcement Learning to Approximate Mixed-Integer Allocation Solutions</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/reinforcement-learning-to-approximate-mixed-integer-allocation-solutions-on-simulated-data-ce8f770fdb5b?source=collection_home---4------19-----------------------" data-action-source="collection_home---4------19-----------------------" data-post-id="ce8f770fdb5b"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Reinforcement Learning to Approximate Mixed-Integer Allocation Solutions</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Training a Neural Network with Reinforcement Learning on Simulated Data</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2022-10-25T17:23:50.167Z">Oct 25, 2022</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="7 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------20-----------------------" data-post-id="4a739953076a" data-index="20" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/neat-time-series-aggregations-with-core-pyspark-4a739953076a?source=collection_home---4------20-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/neat-time-series-aggregations-with-core-pyspark-4a739953076a?source=collection_home---4------20-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*OlYezg8D3CGEHlmDTsHpUg.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Time Series Aggregations with Core PySpark</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/neat-time-series-aggregations-with-core-pyspark-4a739953076a?source=collection_home---4------20-----------------------" data-action-source="collection_home---4------20-----------------------" data-post-id="4a739953076a"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Time Series Aggregations with Core&nbsp;PySpark</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">Moving window aggregation strategies with core PySpark and visualizations with&nbsp;Plotly</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2022-02-11T06:41:54.928Z">Feb 11, 2022</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="10 min read"></span><span class="u-paddingLeft4"><span class="svgIcon svgIcon--star svgIcon--15px"><svg class="svgIcon-use" width="15" height="15"><path d="M7.438 2.324c.034-.099.09-.099.123 0l1.2 3.53a.29.29 0 00.26.19h3.884c.11 0 .127.049.038.111L9.8 8.327a.271.271 0 00-.099.291l1.2 3.53c.034.1-.011.131-.098.069l-3.142-2.18a.303.303 0 00-.32 0l-3.145 2.182c-.087.06-.132.03-.099-.068l1.2-3.53a.271.271 0 00-.098-.292L2.056 6.146c-.087-.06-.071-.112.038-.112h3.884a.29.29 0 00.26-.19l1.2-3.52z"></path></svg></span></span></div></div></div></div></div></div><div class="col u-xs-size12of12 js-trackPostPresentation u-paddingLeft12 u-marginBottom15 u-paddingRight12 u-size4of12" data-source="collection_home---4------21-----------------------" data-post-id="a2389785a3f5" data-index="21" data-scroll="native"><div class="u-lineHeightBase postItem"><a href="https://medium.com/init-deep-dive/pixel-shift-motion-correction-ios-a2389785a3f5?source=collection_home---4------21-----------------------" data-action="open-post" data-action-value="https://medium.com/init-deep-dive/pixel-shift-motion-correction-ios-a2389785a3f5?source=collection_home---4------21-----------------------" class="u-block u-xs-height170 u-height172 u-backgroundSizeCover u-backgroundOriginBorderBox u-backgroundColorGrayLight u-borderLighter" style="background-image: url(&quot;https://cdn-images-1.medium.com/max/360/1*VDbtWyQVUljkZSDvXEWg-w.png&quot;); background-position: 50% 50% !important;"><span class="u-textScreenReader">Pixel Shift Motion Correction — iOS</span></a></div><div class="col u-xs-marginBottom10 u-paddingLeft0 u-paddingRight0 u-paddingTop15 u-marginBottom30"><a class="" href="https://medium.com/init-deep-dive/pixel-shift-motion-correction-ios-a2389785a3f5?source=collection_home---4------21-----------------------" data-action-source="collection_home---4------21-----------------------" data-post-id="a2389785a3f5"><h3 class="u-contentSansBold u-lineHeightTightest u-xs-fontSize24 u-paddingBottom2 u-paddingTop5 u-fontSize32"><div class="u-letterSpacingTight u-lineHeightTighter u-breakWord u-textOverflowEllipsis u-lineClamp3 u-fontSize24">Pixel Shift Motion Correction — iOS</div></h3><div class="u-contentSansThin u-lineHeightBaseSans u-fontSize24 u-xs-fontSize18 u-textColorNormal u-baseColor--textNormal"><div class="u-fontSize18 u-letterSpacingTight u-lineHeightTight u-marginTop7 u-textColorNormal u-baseColor--textNormal">The objective is to implement a lateral movement motion correction algorithm on a iOS device. The algorithm processes the video feed&nbsp;in…</div></div></a><div class="u-clearfix u-marginTop20"><div class="u-flexCenter"><div class="postMetaInline-avatar u-flex0"><a class="link u-baseColor--link avatar" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto"><img src="https://cdn-images-1.medium.com/fit/c/32/32/1*3XzVpwnrPsYfintf7NdwJw.png" class="avatar-image u-size36x36 u-xs-size32x32" alt="Go to the profile of Rohan Kotwani"></a></div><div class="postMetaInline postMetaInline-authorLockup ui-captionStrong u-flex1 u-noWrapWithEllipsis"><a class="ds-link ds-link--styleSubtle link link--darken link--accent u-accentColor--textNormal u-accentColor--textDarken" href="https://medium.com/@rohankotwani" data-action="show-user-card" data-action-value="7db535a7549e" data-action-type="hover" data-user-id="7db535a7549e" dir="auto">Rohan Kotwani</a><div class="ui-caption u-fontSize12 u-baseColor--textNormal u-textColorNormal js-postMetaInlineSupplemental"><time datetime="2019-02-08T03:04:30.361Z">Feb 7, 2019</time><span class="middotDivider u-fontSize12"></span><span class="readingTime" title="4 min read"></span></div></div></div></div></div></div></div></section>
"""

# %%
# html

# %%
from bs4 import BeautifulSoup

# Assume `html` is your raw HTML string
soup = BeautifulSoup(html, "html.parser")

posts = []

# Each post is inside a div with `data-post-id`
for post in soup.find_all("div", attrs={"data-post-id": True}):
    try:
        # Find the title (inside an <h3> -> <div>)
        title_div = post.find("h3")
        title = title_div.get_text(strip=True) if title_div else None

        # Find the subtitle (inside .u-fontSize18)
        subtitle_div = post.find("div", class_="u-fontSize18")
        subtitle = subtitle_div.get_text(strip=True) if subtitle_div else None

        # Find the post URL (first <a> with href containing medium.com/init-deep-dive)
        url_tag = post.find("a", href=True)
        url = url_tag["href"] if url_tag else None

        if title and subtitle and url:
            posts.append((title.replace("\xa0", " "), subtitle.replace("\xa0", " "), url.replace("?source=collection_home---4------21-----------------------", "")))
    except Exception as e:
        print("Skipping a post due to error:", e)

# Example: print all posts
for p in posts:
    print(p)
# Out:
# ('My Reflections on Tech & AI in 2024', 'Notes on My Personal Growth and Opinions on the Benefits of GenAI', 'https://medium.com/init-deep-dive/my-reflections-on-tech-ai-in-2024-f7a6fcf7b814?source=collection_home---4------1-----------------------')
# ('[LangGraph] Self-Correcting Code Assistant + Rag Search', 'AI Agent for Code Generation with RAG + Self-Reflection', 'https://medium.com/init-deep-dive/langgraph-self-correcting-code-assistant-rag-search-74b575d02505?source=collection_home---4------2-----------------------')
# ('LinkedIn Easy-Apply Bot with ChatGPT 4o and LangGraph Agent', 'Web Automation and Data Collection', 'https://medium.com/init-deep-dive/linkedin-easy-apply-bot-with-chatgpt-4o-and-langgraph-agent-4ab9f50e017c?source=collection_home---4------3-----------------------')
# ...
